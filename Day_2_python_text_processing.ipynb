# %% [markdown]
# <a href="https://colab.research.google.com/github/pari12-1/ABTalks/blob/main/Day_2_python_text_processing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hi , my name is parita!")
print("i like doing programming.")
# Out:
# Hi , my name is parita!
# i like doing programming.

# %%
from collections import Counter

# Take a sentence from the user
sentence = input("Enter a sentence: ")

# Convert sentence to lowercase
sentence = sentence.lower()

# Split sentence into words
words = sentence.split()

# Count the frequency of each word
word_frequency = Counter(words)

# Print the result
print("\nWord Frequency:")

for word, count in word_frequency.items():
    print(word, ":", count)
# Out:
# Enter a sentence: my name is pari and pari is good
#
# Word Frequency:
# my : 1
# name : 1
# is : 2
# pari : 2
# and : 1
# good : 1

# %% [markdown]
# converting it to lower case , each word and normalizing the white space . [ removing the white space. ]

# %%
import string

# Take text from the user
text = input("Enter text: ")

# Convert text to lowercase
cleaned_text = text.lower()

# Remove punctuation
cleaned_text = cleaned_text.translate(
    str.maketrans("", "", string.punctuation)
)

# Normalize whitespace
cleaned_text = " ".join(cleaned_text.split())

# Print final cleaned text
print("\nOriginal Text:")
print(text)

print("\nCleaned Text:")
print(cleaned_text)
# Out:
# Enter text: hello !, the world seems good , world is big and world is large!!
#
# Original Text:
# hello !, the world seems good , world is big and world is large!!
#
# Cleaned Text:
# hello the world seems good world is big and world is large
